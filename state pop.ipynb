# %%
#import files
import os
import json
import pprint
import pandas as pd
import numpy as np
# import requests

# %%
df1 = pd.read_csv('state-population-table.csv')
df2 = pd.read_csv('state-population-table(1).csv')

df1 = df1.append(df2, ignore_index=True)

df1=df1.drop(columns=['rank','percent','growth','growthSince2010','pop2019','fips' ])
df1=df1[df1.state != 'Puerto Rico']

abbrevs={
    "AL": "Alabama",
    "AK": "Alaska",
    "AS": "American Samoa",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware",
    "DC": "District of Columbia",
    "FM": "Federated States Of Micronesia",
    "FL": "Florida",
    "GA": "Georgia",
    "GU": "Guam",
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL": "Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MH": "Marshall Islands",
    "MD": "Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT": "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH": "New Hampshire",
    "NJ": "New Jersey",
    "NM": "New Mexico",
    "NY": "New York",
    "NC": "North Carolina",
    "ND": "North Dakota",
    "MP": "Northern Mariana Islands",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PW": "Palau",
    "PA": "Pennsylvania",
    "PR": "Puerto Rico",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee",
    "TX": "Texas",
    "UT": "Utah",
    "VT": "Vermont",
    "VI": "Virgin Islands",
    "VA": "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming"
}

abbrev_to_us_state = dict(map(reversed, abbrevs.items()))
df1.state.replace(abbrev_to_us_state, inplace=True)
df1=df1.drop(columns=['pop2023', 'pop2022', 'growthRate'])
df1.to_csv('filter_state.csv')

# %%
df1
# Out:
#                    state    densityMi   pop2020   pop2010    area
# 0                     CA    249.81347  39501653  37253956  155779
# 1                     TX    116.75553  29232474  25145561  261232
# 2                     FL    422.59351  21589602  18801310   53625
# 3                     NY    413.71663  20108296  19378102   47126
# 4                     PA    289.02749  12994440  12702379   44743
# 5                     IL    224.74459  12786580  12830632   55519
# 6                     OH    287.50579  11797517  11536504   40861
# 7                     GA    191.91701  10729828   9687653   57513
# 8                     NC    222.79940  10449445   9535483   48618
# 9                     MI    177.41244  10069577   9883640   56539
# 10                    NJ   1258.55820   9271689   8791894    7354
# 11                    VA    220.55895   8636471   8001024   39490
# 12                    WA    117.83476   7724031   6724540   66456
# ...
